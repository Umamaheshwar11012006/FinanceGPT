# %% [markdown]
# # FinanceGPT - Advanced Chatbot UI
#
# This notebook is used for:
#
# - Building advanced chatbot interface
# - Adding conversation history
# - Creating ChatGPT-style interaction
# - Improving user experience
# - Understanding multi-turn AI conversations

# %%
# !pip install gradio -q

# !pip install transformers accelerate bitsandbytes -q

# %%
import gradio as gr

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    pipeline
)

# %%
model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

model = AutoModelForCausalLM.from_pretrained(
    model_name
)

tokenizer = AutoTokenizer.from_pretrained(
    model_name
)

print("FinanceGPT model loaded successfully.")

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)

print("Pipeline created successfully.")

# %%
def financegpt_chat(message, history):

    prompt = f"""
You are FinanceGPT, a helpful AI finance assistant.

User: {message}

Assistant:
"""

    result = pipe(
        prompt,
        max_new_tokens=50,
        do_sample=True,
        temperature=0.7
    )

    generated_text = result[0]["generated_text"]

    response = generated_text.split("Assistant:")[-1].strip()

    return response

# %%
chatbot = gr.ChatInterface(
    fn=financegpt_chat,
    title="FinanceGPT",
    description="Your AI-powered finance assistant.",
    theme="soft"
)

# %%
chatbot.launch()
