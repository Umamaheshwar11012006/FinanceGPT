# %%
# !pip install transformers datasets peft trl accelerate bitsandbytes gradio

# %%
# !pip install peft accelerate gradio huggingface_hub -q

# %%
import transformers, datasets, peft, trl, bitsandbytes
print("transformers:", transformers.__version__)
print("datasets:", datasets.__version__)
print("peft:", peft.__version__)
print("trl:", trl.__version__)
print("All good! Ready to build FinanceGPT.")

# %%
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model="gpt2"
)

result = pipe(
    "Indian stock market today",
    max_new_tokens=50
)

print(result[0]["generated_text"])
